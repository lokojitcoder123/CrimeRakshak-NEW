# %%
import os
import sys
from dotenv import load_dotenv

sys.path.append(os.path.abspath("."))
load_dotenv(".env")

from app.core.database import SessionLocal
from app.services.auth_service import register_user, get_user_by_username
from app.models.rbac import Role

db = SessionLocal()
try:
    admin_role = db.query(Role).filter_by(role_name="admin").first()
    if not admin_role:
        admin_role = Role(role_name="admin", permissions={"all": True})
        db.add(admin_role)
        db.commit()
        print("Created 'admin' role.")
        
    viewer_role = db.query(Role).filter_by(role_name="viewer").first()
    if not viewer_role:
        viewer_role = Role(role_name="viewer", permissions={"read": True})
        db.add(viewer_role)
        db.commit()
        print("Created 'viewer' role.")
        
    user = get_user_by_username(db, "admin")
    if not user:
        user = register_user(
            db,
            username="admin",
            email="admin@example.com",
            password="ChangeMe123!",
            role_names=["admin"]
        )
        print("Successfully created 'admin' user with password 'ChangeMe123!'.")
    else:
        print("Admin user already exists.")
except Exception as e:
    print(f"Failed to create admin user: {e}")
    db.rollback()
finally:
    db.close()
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[4], line 8
#       5 sys.path.append(os.path.abspath("."))
#       6 load_dotenv(".env")
# ----> 8 from app.core.database import SessionLocal
#       9 from app.services.auth_service import register_user, get_user_by_username
#      10 from app.models.rbac import Role
#
# File c:\crime ai\CrimeRakshak\backend\app\core\database.py:7
#       4 from sqlalchemy import create_engine
#       5 from sqlalchemy.orm import DeclarativeBase, sessionmaker
# ----> 7 from app.core.config import settings
#       9 engine = create_engine(
#      10     settings.sqlalchemy_database_uri,
#      11     pool_pre_ping=True,   # transparently recycle connections dropped by the server
#    (...)
#      14     future=True,
#      15 )
#      17 SessionLocal = sessionmaker(
#      18     bind=engine,
#      19     autoflush=False,
#    (...)
#      22     future=True,
#      23 )
#
# File c:\crime ai\CrimeRakshak\backend\app\core\config.py:12
#       9 from typing import List
#      11 from pydantic import field_validator
# ---> 12 from pydantic_settings import BaseSettings, NoDecode, SettingsConfigDict
#      13 from typing_extensions import Annotated
#      16 class Settings(BaseSettings):
#
# ImportError: cannot import name 'NoDecode' from 'pydantic_settings' (c:\Users\LOKOJIT\anaconda3\Lib\site-packages\pydantic_settings\__init__.py)
